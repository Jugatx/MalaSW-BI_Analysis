# %%
import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

# %% [markdown]
# # Importing 2018 finance reporting file

# %%
df_anual_2018 = pd.read_excel('../datasets/Estados Financieros/Estados Financieros Mala Swimwear 2018.xlsx', 
            sheet_name='Analítica',skiprows=np.arange(0,3),
            usecols= 'A:M')
pd.set_option("display.precision", 2)

# %%
df_anual_2018
# Out:
#                                           Enero   Febrero     Marzo     Abril  \
# 0                     I N G R E S O S       NaN       NaN       NaN       NaN
# 1                              Ventas       NaN       NaN       NaN       NaN
# 2                      Ventas Mayoreo  10407.00      0.00  34880.00      0.00
# 3                      Ventas Menudeo   9090.00  18330.00  59392.00   6440.00
# 4             Ventas Ferias de Diseño      0.00      0.00      0.00  26702.50
# 5                 Ventas Consignación  13056.00   4670.50      0.00  27768.01
# 6                     Ventas en línea      0.00      0.00      0.00      0.00
# 7                      Otros Ingresos      0.00  11750.00    750.00    160.00
# 8                                 NaN       NaN       NaN       NaN       NaN
# 9                 TOTAL  VENTAS NETAS  32553.00  34750.50  95022.00  61070.51
# 10                                          NaN       NaN       NaN       NaN
# ...

# %%
df_anual_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0               50 non-null     object
#  1   Enero       44 non-null     float64
#  2   Febrero     44 non-null     float64
#  3   Marzo       44 non-null     float64
#  4   Abril       44 non-null     float64
#  5   Mayo        44 non-null     float64
#  6   Junio       44 non-null     float64
#  7   Julio       44 non-null     float64
#  8   Agosto      44 non-null     float64
#  9   Septiembre  44 non-null     float64
#  10  Octubre     44 non-null     float64
#  11  Noviembre   43 non-null     float64
#  12  Diciembre   44 non-null     float64
# dtypes: float64(12), object(1)
# memory usage: 5.8+ KB

# %%
df_anual_2018 = df_anual_2018.dropna()

# %%
#Saving 2018 anual finance reporting
df_anual_2018.to_csv('df_anual_2018.csv')

# %% [markdown]
# # Importing 2019 finance reporting file, PDF format

# %%
# !pip install tabula-py

# %%
import tabula
import pandas as pd
file = ('../datasets/Estados Financieros/Analítica Enero a Septiembre 2019.pdf')

tabula.convert_into(file, "df_anual_2019_.csv", pages = 'all')
 
#df_anual_2019_1 = tabula.read_pdf(file,stream=True, pages= 'all' )
#df_anual_2019_2 = tabula.read_pdf(file,stream=True, pages= 2 )

# %%
with open('df_anual_2019_.csv') as f:
    print(f.encoding)
# Out:
# cp1252

# %%
df_anual_2019_ = pd.read_csv('../datasets/Estados Financieros/df_anual_2019_.csv', thousands=',', encoding='cp1252')
#pd.set_option("display.precision", 2)

# %%
df_anual_2019_
# Out:
#                            Unnamed: 0    Enero  Febrero     Marzo     Abril  \
# 0                     I N G R E S O S      NaN      NaN       NaN       NaN
# 1                              Ventas      NaN      NaN       NaN       NaN
# 2                      Ventas Mayoreo  13448.0   6910.0   11076.0   17802.0
# 3                      Ventas Menudeo  23970.0  25019.0   33379.0   63307.0
# 4             Ventas Ferias de Diseño      0.0      0.0   68906.0       0.0
# 5                 Ventas Consignación  16048.0  17486.0   17352.0   23178.0
# 6                     Ventas en línea   9866.0   2530.0   10251.0    7321.0
# 7                      Otros Ingresos   1889.0      0.0       0.0       0.0
# 8                 TOTAL  VENTAS NETAS  65220.0  51945.0  140964.0  111608.0
# 9                                 NaN      NaN      NaN       NaN       NaN
# 10                      E G R E S O S      NaN      NaN       NaN       NaN
# ...

# %%
df_anual_2019_ = df_anual_2019_.dropna()

# %%
df_anual_2019_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 2 to 52
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  47 non-null     object
#  1   Enero       47 non-null     float64
#  2   Febrero     47 non-null     float64
#  3   Marzo       47 non-null     float64
#  4   Abril       47 non-null     float64
#  5   Mayo        47 non-null     float64
#  6   Junio       47 non-null     float64
#  7   Julio       47 non-null     float64
#  8   Agosto      47 non-null     float64
#  9   Septiembre  47 non-null     float64
#  10  Acumulado   47 non-null     float64
# dtypes: float64(10), object(1)
# memory usage: 4.4+ KB

# %%
df_anual_2019_ = df_anual_2019_.replace(',', '')

# %%
df_anual_2019_
# Out:
#                            Unnamed: 0    Enero  Febrero     Marzo     Abril  \
# 2                      Ventas Mayoreo  13448.0   6910.0   11076.0   17802.0
# 3                      Ventas Menudeo  23970.0  25019.0   33379.0   63307.0
# 4             Ventas Ferias de Diseño      0.0      0.0   68906.0       0.0
# 5                 Ventas Consignación  16048.0  17486.0   17352.0   23178.0
# 6                     Ventas en línea   9866.0   2530.0   10251.0    7321.0
# 7                      Otros Ingresos   1889.0      0.0       0.0       0.0
# 8                 TOTAL  VENTAS NETAS  65220.0  51945.0  140964.0  111608.0
# 12                      Materia Prima      0.0      0.0    7521.0    4611.0
# 13                   Vitta Colombiana   6861.0   6861.0    6861.0    6861.0
# 14                              Forro   1050.0   1050.0    1050.0    1050.0
# 15              Etiquetas y Embalajes   1649.0   1649.0    1649.0    2179.0
# ...

# %%
#Saving 2019 anual finance reporting
df_anual_2019_.to_csv('df_anual_2019.csv')
